# %%
import random
import pandas as pd
import hopsworks

BACKFILL=False

# %%
norm1 = pd.read_csv('/Users/magdalenabaran/Desktop/Project_Group_75/data_extract/NORM1.csv')
norm2 = pd.read_csv('/Users/magdalenabaran/Desktop/Project_Group_75/data_extract/NORM2.csv')
norm3 = pd.read_csv('/Users/magdalenabaran/Desktop/Project_Group_75/data_extract/NORM3.csv')

# %%
norm1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23571 entries, 0 to 23570
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   time          23571 non-null  object
#  1   battery       23571 non-null  float64
#  2   temperature   23571 non-null  float64
#  3   x             23571 non-null  int64
#  4   y             23571 non-null  int64
#  5   z             23571 non-null  int64
#  6   0_radar       23571 non-null  int64
#  7   1_radar       23571 non-null  int64
#  8   2_radar       23571 non-null  int64
#  9   3_radar       23571 non-null  int64
#  10  4_radar       23571 non-null  int64
#  11  5_radar       23571 non-null  int64
#  12  6_radar       23571 non-null  int64
#  13  7_radar       23571 non-null  int64
#  14  package_type  23571 non-null  object
#  15  f_cnt         23571 non-null  int64
#  16  dr            23571 non-null  int64
#  17  snr           23567 non-null  float64
# ...

# %%
norm2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40487 entries, 0 to 40486
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   time          40487 non-null  object
#  1   battery       40487 non-null  float64
#  2   temperature   40487 non-null  float64
#  3   x             40487 non-null  int64
#  4   y             40487 non-null  int64
#  5   z             40487 non-null  int64
#  6   0_radar       40487 non-null  int64
#  7   1_radar       40487 non-null  int64
#  8   2_radar       40487 non-null  int64
#  9   3_radar       40487 non-null  int64
#  10  4_radar       40487 non-null  int64
#  11  5_radar       40487 non-null  int64
#  12  6_radar       40487 non-null  int64
#  13  7_radar       40487 non-null  int64
#  14  package_type  40487 non-null  object
#  15  f_cnt         40487 non-null  int64
#  16  dr            40487 non-null  int64
#  17  snr           40454 non-null  float64
# ...

# %%
norm3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22404 entries, 0 to 22403
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   time          22404 non-null  object
#  1   battery       22404 non-null  float64
#  2   temperature   22404 non-null  float64
#  3   x             22404 non-null  int64
#  4   y             22404 non-null  int64
#  5   z             22404 non-null  int64
#  6   0_radar       22404 non-null  int64
#  7   1_radar       22404 non-null  int64
#  8   2_radar       22404 non-null  int64
#  9   3_radar       22404 non-null  int64
#  10  4_radar       22404 non-null  int64
#  11  5_radar       22404 non-null  int64
#  12  6_radar       22404 non-null  int64
#  13  7_radar       22404 non-null  int64
#  14  package_type  22404 non-null  object
#  15  f_cnt         22404 non-null  int64
#  16  dr            22404 non-null  int64
#  17  snr           22344 non-null  float64
# ...

# %%
norm1['magnitude'] = (norm1['x']**2 + norm1['y']**2 + norm1['z']**2)**0.5
norm2['magnitude'] = (norm2['x']**2 + norm2['y']**2 + norm2['z']**2)**0.5
norm3['magnitude'] = (norm3['x']**2 + norm3['y']**2 + norm3['z']**2)**0.5

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = norm1[['x','y','z','temperature']]
df2 = norm2[['x','y','z','temperature']]
df3 = norm3[['x','y','z','temperature']]

# %%
sns.pairplot(df)
plt.show()

# %%
sns.pairplot(df2)
plt.show()

# %%
sns.pairplot(df3)
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].scatter(df['temperature'], df['x'])
axs[0].set_title('Temperature vs X')
axs[0].set_xlabel('Temperature')
axs[0].set_ylabel('X')

axs[1].scatter(df['temperature'], df['z'])
axs[1].set_title('Temperature vs Z')
axs[1].set_xlabel('Temperature')
axs[1].set_ylabel('Z')

axs[2].scatter(df['temperature'], df['y'])
axs[2].set_title('Temperature vs Y')
axs[2].set_xlabel('Temperature')
axs[2].set_ylabel('Y')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].scatter(df2['temperature'], df2['x'])
axs[0].set_title('Temperature vs X')
axs[0].set_xlabel('Temperature')
axs[0].set_ylabel('X')

axs[1].scatter(df2['temperature'], df2['z'])
axs[1].set_title('Temperature vs Z')
axs[1].set_xlabel('Temperature')
axs[1].set_ylabel('Z')

axs[2].scatter(df2['temperature'], df2['y'])
axs[2].set_title('Temperature vs Y')
axs[2].set_xlabel('Temperature')
axs[2].set_ylabel('Y')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].scatter(df3['temperature'], df3['x'])
axs[0].set_title('Temperature vs X')
axs[0].set_xlabel('Temperature')
axs[0].set_ylabel('X')

axs[1].scatter(df3['temperature'], df3['z'])
axs[1].set_title('Temperature vs Z')
axs[1].set_xlabel('Temperature')
axs[1].set_ylabel('Z')

axs[2].scatter(df3['temperature'], df3['y'])
axs[2].set_title('Temperature vs Y')
axs[2].set_xlabel('Temperature')
axs[2].set_ylabel('Y')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(norm1['temperature'], norm1['magnitude'])
plt.title('Temperature vs Magnitude')
plt.xlabel('Temperature')
plt.ylabel('Magnitude')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(norm2['temperature'], norm2['magnitude'])
plt.title('Temperature vs Magnitude')
plt.xlabel('Temperature')
plt.ylabel('Magnitude')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(norm3['temperature'], norm3['magnitude'])
plt.title('Temperature vs Magnitude')
plt.xlabel('Temperature')
plt.ylabel('Magnitude')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

norm1['x'] = scaler.fit_transform(norm1[['x']])
norm1['y'] = scaler.fit_transform(norm1[['y']])
norm1['z'] = scaler.fit_transform(norm1[['z']])

# %%
norm1['temperature'] = scaler.fit_transform(norm1[['temperature']])

# %%
norm1['magnitude'] = scaler.fit_transform(norm1[['magnitude']])

# %%
norm1.head(5)
# Out:
# 2024-05-27 21:51:17,863 WARNING: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#
# 2024-05-27 21:51:17,866 WARNING: FutureWarning: RangeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#                       time  battery  temperature         x         y  \
# 0  2023-09-30 23:41:42.121      3.1     0.816535  0.399246  0.544961
# 1  2023-09-30 23:51:40.121      3.1     0.816535  0.398168  0.544574
# 2  2023-10-01 00:01:40.121      3.1     0.816535  0.398168  0.544574
# 3  2023-10-01 00:11:42.207      3.1     0.818504  0.398707  0.544186
# 4  2023-10-01 00:21:43.207      3.1     0.818504  0.398168  0.544186
#
#           z  0_radar  1_radar  2_radar  3_radar  4_radar  5_radar  6_radar  \
# 0  0.656299        6        3        4        4        5        5        5
# ...

# %%
norm1 = norm1.drop(columns=['battery','package_type','f_cnt','dr','snr','rssi'])

# %%
norm1.rename(columns={
    '0_radar': 'radar_0',
    '1_radar': 'radar_1',
    '2_radar': 'radar_2',
    '3_radar': 'radar_3',
    '4_radar': 'radar_4',
    '5_radar': 'radar_5',
    '6_radar': 'radar_6',
    '7_radar': 'radar_7'
}, inplace=True)

# %%
norm1.head()
# Out:
# 2024-05-27 21:51:24,064 WARNING: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#
# 2024-05-27 21:51:24,070 WARNING: FutureWarning: RangeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#                       time  temperature         x         y         z  \
# 0  2023-09-30 23:41:42.121     0.816535  0.399246  0.544961  0.656299
# 1  2023-09-30 23:51:40.121     0.816535  0.398168  0.544574  0.656075
# 2  2023-10-01 00:01:40.121     0.816535  0.398168  0.544574  0.655404
# 3  2023-10-01 00:11:42.207     0.818504  0.398707  0.544186  0.655628
# 4  2023-10-01 00:21:43.207     0.818504  0.398168  0.544186  0.656523
#
#    radar_0  radar_1  radar_2  radar_3  radar_4  radar_5  radar_6  radar_7  \
# 0        6        3        4        4        5        5        5        1
# ...

# %%
norm1.reset_index(inplace=True)
norm1.rename(columns={'index': 'id'}, inplace=True)

# %%
import requests
import json
import io
import base64
 
url = "url"
 
payload = json.dumps({
    "dev_eui": "70B3D56380000150",
    "from": "2024-03-01",
    "to": "2024-04-30"
})
 
username = "username"
pwd = "pwd"
basic_auth = base64.b64encode(f"{username}:{pwd}".encode())
 
headers = {
    'Content-Type': 'application/json',
    'Authorization': f'Basic {basic_auth.decode("utf-8")}'
}
 
response = requests.request("GET", url, headers=headers, data=payload)
 
if response.status_code != 200:
    exit(13)
 
csv_data = response.text
df50 = pd.read_csv(io.StringIO(csv_data))

# %%
df50
# Out:
# 2024-05-27 23:26:54,235 WARNING: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#                             time  battery  temperature    x    y   z  0_radar  \
# 0     2024-03-01 00:14:23.138000    3.592         6.75 -455  291  77      NaN
# 1     2024-03-01 00:14:31.951000      NaN          NaN -453  289  77      NaN
# 2     2024-03-01 00:29:13.951000      NaN          NaN -457  294  75      NaN
# 3     2024-03-01 00:44:05.951000    3.587         6.75 -457  293  72      NaN
# 4     2024-03-01 00:44:16.873000      NaN          NaN -459  287  78      NaN
# ...                          ...      ...          ...  ...  ...  ..      ...
# 8150  2024-04-29 23:05:19.588000      NaN          NaN -474  305  85      NaN
# 8151  2024-04-29 23:20:16.588000      NaN          NaN -481  306  79      NaN
# 8152  2024-04-29 23:35:03.588000    3.615        10.25 -480  298  77      NaN
# ...

# %%
df50.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8155 entries, 0 to 8154
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   time           8155 non-null   object
#  1   battery        3021 non-null   float64
#  2   temperature    3021 non-null   float64
#  3   x              8155 non-null   int64
#  4   y              8155 non-null   int64
#  5   z              8155 non-null   int64
#  6   0_radar        0 non-null      float64
#  7   1_radar        0 non-null      float64
#  8   2_radar        0 non-null      float64
#  9   3_radar        0 non-null      float64
#  10  4_radar        0 non-null      float64
#  11  5_radar        0 non-null      float64
#  12  6_radar        0 non-null      float64
#  13  7_radar        0 non-null      float64
#  14  package_type   8155 non-null   object
#  15  f_cnt          8155 non-null   int64
#  16  dr             8155 non-null   int64
# ...

# %%
df50['magnitude'] = (df50['x']**2 + df50['y']**2 + df50['z']**2)**0.5

# %%
df50['temperature'] = df50['temperature'].fillna(method='bfill')
df50['temperature'] = df50['temperature'].fillna(method='ffill')
# Out:
# 2024-05-27 23:27:01,209 WARNING: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# 2024-05-27 23:27:01,212 WARNING: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.

# %%
df50.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8155 entries, 0 to 8154
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   time           8155 non-null   object
#  1   battery        3021 non-null   float64
#  2   temperature    8155 non-null   float64
#  3   x              8155 non-null   int64
#  4   y              8155 non-null   int64
#  5   z              8155 non-null   int64
#  6   0_radar        0 non-null      float64
#  7   1_radar        0 non-null      float64
#  8   2_radar        0 non-null      float64
#  9   3_radar        0 non-null      float64
#  10  4_radar        0 non-null      float64
#  11  5_radar        0 non-null      float64
#  12  6_radar        0 non-null      float64
#  13  7_radar        0 non-null      float64
#  14  package_type   8155 non-null   object
#  15  f_cnt          8155 non-null   int64
#  16  dr             8155 non-null   int64
# ...

# %%
df50['x'] = scaler.fit_transform(df50[['x']])
df50['z'] = scaler.fit_transform(df50[['z']])
df50['y'] = scaler.fit_transform(df50[['y']])
df50['magnitude'] = scaler.fit_transform(df50[['magnitude']])
df50['temperature'] = scaler.fit_transform(df50[['temperature']])

# %%
df50 = df50.drop(columns=['battery', 'hw_fw_version', 'package_type','f_cnt','dr','snr','rssi', '0_radar', '1_radar', '2_radar', '3_radar', '4_radar', '5_radar', '6_radar', '7_radar'])

# %%
df50.head()
# Out:
# 2024-05-27 23:27:12,839 WARNING: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#
# 2024-05-27 23:27:12,842 WARNING: FutureWarning: RangeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#                          time  temperature         x         y         z  \
# 0  2024-03-01 00:14:23.138000     0.119048  0.362686  0.340530  0.397516
# 1  2024-03-01 00:14:31.951000     0.119048  0.363786  0.338567  0.397516
# 2  2024-03-01 00:29:13.951000     0.119048  0.361585  0.343474  0.395445
# 3  2024-03-01 00:44:05.951000     0.119048  0.361585  0.342493  0.392340
# 4  2024-03-01 00:44:16.873000     0.142857  0.360484  0.336605  0.398551
#
#    magnitude
# 0   0.359387
# 1   0.357248
# 2   0.361729
# 3   0.360996
# 4   0.360461

# %%
df50.reset_index(inplace=True)
df50.rename(columns={'index': 'id'}, inplace=True)

# %%
df50
# Out:
# 2024-05-27 23:27:18,056 WARNING: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#         id                        time  temperature         x         y  \
# 0        0  2024-03-01 00:14:23.138000     0.119048  0.362686  0.340530
# 1        1  2024-03-01 00:14:31.951000     0.119048  0.363786  0.338567
# 2        2  2024-03-01 00:29:13.951000     0.119048  0.361585  0.343474
# 3        3  2024-03-01 00:44:05.951000     0.119048  0.361585  0.342493
# 4        4  2024-03-01 00:44:16.873000     0.142857  0.360484  0.336605
# ...    ...                         ...          ...       ...       ...
# 8150  8150  2024-04-29 23:05:19.588000     0.785714  0.352229  0.354269
# 8151  8151  2024-04-29 23:20:16.588000     0.785714  0.348376  0.355250
# 8152  8152  2024-04-29 23:35:03.588000     0.785714  0.348927  0.347399
# 8153  8153  2024-04-29 23:35:15.296000     0.785714  0.348376  0.350343
# ...

# %%
project = hopsworks.login()
fs = project.get_feature_store()
# Out:
# Connection closed.
# Connected. Call `.close()` to terminate connection gracefully.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/549021
# Connected. Call `.close()` to terminate connection gracefully.

# %%
fg = fs.create_feature_group(
    name='spot50',
    version=1,
    description='sensor 50 - parking spot 9',
    primary_key=['id'],
    online_enabled=False,
    statistics_config={'histograms': True, 'correlations': True}
)

# %%
fg.insert(df50)
# Out:
# Feature Group created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/549021/fs/544844/fg/855374
# Uploading Dataframe: 0.00% |          | Rows 0/8155 | Elapsed Time: 00:00 | Remaining Time: ?
# Launching job: spot50_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai/p/549021/jobs/named/spot50_1_offline_fg_materialization/executions
# (<hsfs.core.job.Job at 0x2b2e40110>, None)

# %%
url = "url"
 
payload = json.dumps({
    "dev_eui": "70B3D56380000158",
    "from": "2024-03-01",
    "to": "2024-04-30"
})
 
username = "username"
pwd = "pwd"
basic_auth = base64.b64encode(f"{username}:{pwd}".encode())
 
headers = {
    'Content-Type': 'application/json',
    'Authorization': f'Basic {basic_auth.decode("utf-8")}'
}
 
response = requests.request("GET", url, headers=headers, data=payload)
 
if response.status_code != 200:
    exit(13)
 
csv_data = response.text
df58 = pd.read_csv(io.StringIO(csv_data))

# %%
df58
# Out:
# 2024-05-27 23:25:38,434 WARNING: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#                             time  battery  temperature   x    y    z  0_radar  \
# 0     2024-03-01 00:11:15.934000      NaN          NaN  10  174  256      NaN
# 1     2024-03-01 00:26:02.934000    3.603        7.625  12  176  259      NaN
# 2     2024-03-01 00:26:11.892000      NaN          NaN   8  174  255      NaN
# 3     2024-03-01 00:41:07.892000      NaN          NaN   5  172  256      NaN
# 4     2024-03-01 00:55:49.892000    3.601        7.625   7  174  255      NaN
# ...                          ...      ...          ...  ..  ...  ...      ...
# 7945  2024-04-29 23:20:06.055000    3.622       10.750  24  169  283      NaN
# 7946  2024-04-29 23:20:16.181000      NaN          NaN  25  168  283      NaN
# 7947  2024-04-29 23:35:15.181000      NaN          NaN  24  162  280      NaN
# ...

# %%
df58['magnitude'] = (df58['x']**2 + df58['y']**2 + df58['z']**2)**0.5

# %%
df58['temperature'] = df58['temperature'].fillna(method='bfill')
df58['temperature'] = df58['temperature'].fillna(method='ffill')
# Out:
# 2024-05-27 23:25:52,477 WARNING: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# 2024-05-27 23:25:52,492 WARNING: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.

# %%
df58['x'] = scaler.fit_transform(df58[['x']])
df58['z'] = scaler.fit_transform(df58[['z']])
df58['y'] = scaler.fit_transform(df58[['y']])
df58['magnitude'] = scaler.fit_transform(df58[['magnitude']])
df58['temperature'] = scaler.fit_transform(df58[['temperature']])

# %%
df58= df58.drop(columns=['battery', 'hw_fw_version', 'package_type','f_cnt','dr','snr','rssi', '0_radar', '1_radar', '2_radar', '3_radar', '4_radar', '5_radar', '6_radar', '7_radar'])

# %%
df58.reset_index(inplace=True)
df58.rename(columns={'index': 'id'}, inplace=True)

# %%
fg58 = fs.create_feature_group(
    name='spot58',
    version=1,
    description='sensor 58 - parking spot 8',
    primary_key=['id'],
    online_enabled=False,
    statistics_config={'histograms': True, 'correlations': True}
)

# %%
fg58.insert(df58)
# Out:
# Feature Group created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/549021/fs/544844/fg/853365
# Uploading Dataframe: 0.00% |          | Rows 0/7950 | Elapsed Time: 00:00 | Remaining Time: ?
# Launching job: spot58_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai/p/549021/jobs/named/spot58_1_offline_fg_materialization/executions
# (<hsfs.core.job.Job at 0x2b1e1d0a0>, None)

# %%
url = "url"
 
payload = json.dumps({
    "dev_eui": "70B3D56380000159",
    "from": "2024-03-01",
    "to": "2024-04-30"
})
 
username = "username"
pwd = "pwd"
basic_auth = base64.b64encode(f"{username}:{pwd}".encode())
 
headers = {
    'Content-Type': 'application/json',
    'Authorization': f'Basic {basic_auth.decode("utf-8")}'
}
 
response = requests.request("GET", url, headers=headers, data=payload)
 
if response.status_code != 200:
    exit(13)
 
csv_data = response.text
df59 = pd.read_csv(io.StringIO(csv_data))

# %%
df59['magnitude'] = (df59['x']**2 + df59['y']**2 + df59['z']**2)**0.5

# %%
df59['temperature'] = df59['temperature'].fillna(method='bfill')
df59['temperature'] = df59['temperature'].fillna(method='ffill')
# Out:
# 2024-05-27 23:30:29,718 WARNING: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# 2024-05-27 23:30:29,737 WARNING: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.

# %%
df59['x'] = scaler.fit_transform(df59[['x']])
df59['z'] = scaler.fit_transform(df59[['z']])
df59['y'] = scaler.fit_transform(df59[['y']])
df59['magnitude'] = scaler.fit_transform(df59[['magnitude']])
df59['temperature'] = scaler.fit_transform(df59[['temperature']])

# %%
df59= df59.drop(columns=['battery', 'hw_fw_version', 'package_type','f_cnt','dr','snr','rssi', '0_radar', '1_radar', '2_radar', '3_radar', '4_radar', '5_radar', '6_radar', '7_radar'])

# %%
df59.reset_index(inplace=True)
df59.rename(columns={'index': 'id'}, inplace=True)

# %%
df59.head()
# Out:
# 2024-05-27 23:31:16,465 WARNING: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#
# 2024-05-27 23:31:16,468 WARNING: FutureWarning: RangeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#    id                        time  temperature         x         y         z  \
# 0   0  2024-03-01 00:09:37.799000     0.183673  0.744746  0.447257  0.279647
# 1   1  2024-03-01 00:09:47.792000     0.122449  0.747373  0.451477  0.281250
# 2   2  2024-03-01 00:24:59.792000     0.122449  0.746935  0.453165  0.277244
# 3   3  2024-03-01 00:39:46.792000     0.122449  0.746935  0.453165  0.280449
# 4   4  2024-03-01 00:39:58.073000     0.142857  0.749124  0.452321  0.278846
#
#    magnitude
# 0   0.252678
# 1   0.255343
# 2   0.254907
# 3   0.256140
# 4   0.254600

# %%
fg59 = fs.create_feature_group(
    name='spot59',
    version=1,
    description='sensor 589 - parking spot 7',
    primary_key=['id'],
    online_enabled=False,
    statistics_config={'histograms': True, 'correlations': True}
)

# %%
fg59.insert(df59)
# Out:
# Feature Group created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/549021/fs/544844/fg/855375
# Uploading Dataframe: 0.00% |          | Rows 0/7960 | Elapsed Time: 00:00 | Remaining Time: ?
# Launching job: spot59_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai/p/549021/jobs/named/spot59_1_offline_fg_materialization/executions
# (<hsfs.core.job.Job at 0x2b2e429f0>, None)

# %%
url = "url"
 
payload = json.dumps({
    "dev_eui": "70B3D56380000163",
    "from": "2024-03-01",
    "to": "2024-04-30"
})
 
username = "username"
pwd = "pwd"
basic_auth = base64.b64encode(f"{username}:{pwd}".encode())
 
headers = {
    'Content-Type': 'application/json',
    'Authorization': f'Basic {basic_auth.decode("utf-8")}'
}
 
response = requests.request("GET", url, headers=headers, data=payload)
 
if response.status_code != 200:
    exit(13)
 
csv_data = response.text
df63 = pd.read_csv(io.StringIO(csv_data))

# %%
df63['magnitude'] = (df63['x']**2 + df63['y']**2 + df63['z']**2)**0.5

# %%
df63['temperature'] = df63['temperature'].fillna(method='bfill')
df63['temperature'] = df63['temperature'].fillna(method='ffill')
# Out:
# 2024-05-27 23:35:37,620 WARNING: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# 2024-05-27 23:35:37,630 WARNING: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.

# %%
df63['x'] = scaler.fit_transform(df63[['x']])
df63['z'] = scaler.fit_transform(df63[['z']])
df63['y'] = scaler.fit_transform(df63[['y']])
df63['magnitude'] = scaler.fit_transform(df63[['magnitude']])
df63['temperature'] = scaler.fit_transform(df63[['temperature']])

# %%
df63= df63.drop(columns=['battery', 'hw_fw_version', 'package_type','f_cnt','dr','snr','rssi', '0_radar', '1_radar', '2_radar', '3_radar', '4_radar', '5_radar', '6_radar', '7_radar'])

# %%
df63.reset_index(inplace=True)
df63.rename(columns={'index': 'id'}, inplace=True)

# %%
df63.head()
# Out:
# 2024-05-27 23:36:33,481 WARNING: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#
# 2024-05-27 23:36:33,485 WARNING: FutureWarning: RangeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#    id                        time  temperature         x         y         z  \
# 0   0  2024-03-01 00:03:14.160000     0.121212  0.676092  0.719076  0.482979
# 1   1  2024-03-01 00:03:23.812000     0.151515  0.677772  0.720939  0.487234
# 2   2  2024-03-01 00:18:44.812000     0.151515  0.677492  0.720194  0.488298
# 3   3  2024-03-01 00:33:30.812000     0.151515  0.677212  0.722802  0.480851
# 4   4  2024-03-01 00:33:41.753000     0.121212  0.677492  0.719821  0.479787
#
#    magnitude
# 0   0.064944
# 1   0.062081
# 2   0.062925
# 3   0.061198
# 4   0.062871

# %%
fg63 = fs.create_feature_group(
    name='spot63',
    version=1,
    description='sensor 63 - parking spot 6',
    primary_key=['id'],
    online_enabled=False,
    statistics_config={'histograms': True, 'correlations': True}
)

# %%
fg63.insert(df63)
# Out:
# Feature Group created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/549021/fs/544844/fg/855376
# Uploading Dataframe: 0.00% |          | Rows 0/7993 | Elapsed Time: 00:00 | Remaining Time: ?
# Launching job: spot63_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai/p/549021/jobs/named/spot63_1_offline_fg_materialization/executions
# (<hsfs.core.job.Job at 0x2b30077d0>, None)

# %%
url = "url"
 
payload = json.dumps({
    "dev_eui": "70B3D5638000016E",
    "from": "2024-03-01",
    "to": "2024-04-30"
})
 
username = "username"
pwd = "pwd"
basic_auth = base64.b64encode(f"{username}:{pwd}".encode())
 
headers = {
    'Content-Type': 'application/json',
    'Authorization': f'Basic {basic_auth.decode("utf-8")}'
}
 
response = requests.request("GET", url, headers=headers, data=payload)
 
if response.status_code != 200:
    exit(13)
 
csv_data = response.text
df6e = pd.read_csv(io.StringIO(csv_data))

# %%
df6e['magnitude'] = (df6e['x']**2 + df6e['y']**2 + df6e['z']**2)**0.5

# %%
df6e['temperature'] = df6e['temperature'].fillna(method='bfill')
df6e['temperature'] = df6e['temperature'].fillna(method='ffill')
# Out:
# 2024-05-27 23:41:14,070 WARNING: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# 2024-05-27 23:41:14,081 WARNING: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.

# %%
df6e['x'] = scaler.fit_transform(df6e[['x']])
df6e['z'] = scaler.fit_transform(df6e[['z']])
df6e['y'] = scaler.fit_transform(df6e[['y']])
df6e['magnitude'] = scaler.fit_transform(df6e[['magnitude']])
df6e['temperature'] = scaler.fit_transform(df6e[['temperature']])

# %%
df6e= df6e.drop(columns=['battery', 'hw_fw_version', 'package_type','f_cnt','dr','snr','rssi', '0_radar', '1_radar', '2_radar', '3_radar', '4_radar', '5_radar', '6_radar', '7_radar'])

# %%
df6e.reset_index(inplace=True)
df6e.rename(columns={'index': 'id'}, inplace=True)

# %%
df6e.head()
# Out:
# 2024-05-27 23:41:51,338 WARNING: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#
# 2024-05-27 23:41:51,340 WARNING: FutureWarning: RangeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#    id                        time  temperature         x         y         z  \
# 0   0  2024-03-01 00:07:37.474000        0.175  0.471659  0.260373  0.443389
# 1   1  2024-03-01 00:22:35.474000        0.175  0.474779  0.261757  0.441805
# 2   2  2024-03-01 00:22:46.052000        0.225  0.469059  0.261411  0.446556
# 3   3  2024-03-01 00:37:43.052000        0.225  0.470619  0.262448  0.444181
# 4   4  2024-03-01 00:52:37.052000        0.225  0.471139  0.259682  0.445764
#
#    magnitude
# 0   0.138086
# 1   0.135190
# 2   0.140877
# 3   0.139054
# 4   0.139091

# %%
fg6e = fs.create_feature_group(
    name='spot6e',
    version=1,
    description='sensor 6e - parking spot 5',
    primary_key=['id'],
    online_enabled=False,
    statistics_config={'histograms': True, 'correlations': True}
)

# %%
fg6e.insert(df6e)
# Out:
# Feature Group created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/549021/fs/544844/fg/855377
# Uploading Dataframe: 0.00% |          | Rows 0/7763 | Elapsed Time: 00:00 | Remaining Time: ?
# Launching job: spot6e_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai/p/549021/jobs/named/spot6e_1_offline_fg_materialization/executions
# (<hsfs.core.job.Job at 0x2b3007da0>, None)
